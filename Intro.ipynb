# %% [markdown]
# # Introduction
#
# This work is inspired by this paper https://www.elie.net/publication/i-am-a-legend from  Elie and Celine Bursztein and will try to reproduce their findings applying some different ideas.

# %% [markdown]
# ## Load the JSON data
#
# Let's start loading the game cards data from http://hearthstonejson.com/ and loading it to python using the json library.

# %%
import os.path
import json

all_sets_filename = os.path.join('data', 'AllSets.json')

# Uncomment the following lines to update the date file
#import urllib
#urllib.urlretrieve ('http://hearthstonejson.com/json/AllSets.json', all_sets_filename)

with open(all_sets_filename) as fp:
    all_card_sets = json.load(fp, encoding='utf-8')

# %% [markdown]
# ## Collectible cards

# %%
all_cards = sum((v for k, v in all_card_sets.items()
                 if k not in ('Debug', 'Credits', 'Missions', 'System')), list())
# Select only collectible cards
all_collectible_cards = [card for card in all_cards if u'collectible' in card and card['collectible']]
# Remove heroes
all_collectible_cards = [card for card in all_collectible_cards
                         if 'type' in card and card['type'] != 'Hero']
len(all_collectible_cards)
# Out:
# 535

# %% [markdown]
# ## Card tags

# %%
tags = set()
for card in all_collectible_cards:
    tags.update(set(card.keys()))
tags
# Out:
# {u'artist',
#  u'attack',
#  u'collectible',
#  u'cost',
#  u'durability',
#  u'elite',
#  u'faction',
#  u'flavor',
#  u'health',
#  u'howToGet',
#  u'howToGetGold',
#  u'id',
#  u'inPlayText',
#  u'mechanics',
#  u'name',
#  u'playerClass',
#  u'race',
#  u'rarity',
#  u'text',
#  u'type'}

# %%
# Only interested in these tags for pricer purpouses
interest_tags = {u'attack', u'cost', u'durability', u'health', u'id', u'mechanics', u'name',
                 u'playerClass', u'text', u'type'}
all_collectible_cards = [{k: v for k, v in card.items() if k in interest_tags}
                         for card in all_collectible_cards]

# %% [markdown]
# ## Card mechanics

# %%
mechanics = set()
for card in all_collectible_cards:
    if 'mechanics' in card:
        mechanics.update(card['mechanics'])
mechanics
# Out:
# {u'AdjacentBuff',
#  u'AffectedBySpellPower',
#  u'Aura',
#  u'Battlecry',
#  u'Charge',
#  u'Combo',
#  u'Deathrattle',
#  u'Divine Shield',
#  u'Enrage',
#  u'Freeze',
#  u'HealTarget',
#  u'ImmuneToSpellpower',
#  u'Poisonous',
#  u'Secret',
#  u'Silence',
#  u'Spellpower',
#  u'Stealth',
#  u'Taunt',
#  u'Windfury'}

# %% [markdown]
# ## Card types

# %%
types = set()
for card in all_collectible_cards:
    if 'type' in card:
        types.add(card['type'])
types
# Out:
# {u'Minion', u'Spell', u'Weapon'}

# %% [markdown]
# ## Big data with cards

# %%
import pandas
all_collectible_cards_df = pandas.DataFrame(all_collectible_cards)

# Set/modify the pricing attributes
all_collectible_cards_df['intrinsic'] = -1

all_collectible_cards_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 535 entries, 0 to 534
# Data columns (total 11 columns):
# attack         357 non-null float64
# cost           535 non-null int64
# durability     18 non-null float64
# health         339 non-null float64
# id             535 non-null object
# mechanics      279 non-null object
# name           535 non-null object
# playerClass    306 non-null object
# text           517 non-null object
# type           535 non-null object
# intrinsic      535 non-null int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 50.2+ KB

# %% [markdown]
# # Some statistics

# %% [markdown]
# ## Breaking the text

# %%
import re
html_tag_pat = re.compile(r'</?[^>]+>')

def text_breaker(text):
    # Remove presentation characters
    raw_text = html_tag_pat.sub('', text).replace('\n', ' ').replace('  ', ' ')
    # Remove comments
    uncommented_text = re.sub(r'\([^\)]+\)', '', raw_text)
    # replaced_text = re.sub(r'\.', '_', uncommented_text)
    replaced_text = uncommented_text.replace('.', '_')
    return set(map(lambda x: x.strip(), replaced_text.split('_')))

all_collectible_cards_df['text_mechanics'] = all_collectible_cards_df.apply(
    lambda row: text_breaker(row['text']) if isinstance(row['text'], basestring) else [] , axis=1)

#all_collectible_cards_df[~all_collectible_cards_df['text'].isnull() & all_collectible_cards_df['text'].str.contains('"')]['text'].values

# %% [markdown]
# ## Short text mechanics

# %%
text_mechanics = set()
for card in all_collectible_cards_df['text_mechanics']:
    text_mechanics.update(card)
[x for x in text_mechanics if len(x) < 14]
# Out:
# [u'',
#  u'Draw a card',
#  u'Draw 4 cards',
#  u'Charge',
#  u"Can't Attack",
#  u'Stealth',
#  u'Draw 3 cards',
#  u'Gain 5 Armor',
#  u'Windfury',
#  u'Horribly',
#  u'Divine Shield',
#  u'Charge Taunt',
#  u'Draw 2 cards',
#  u'"',
#  u'Taunt',
#  u'Then, it dies',
#  u'Overload:']

# %% [markdown]
# ## Vanilla test

# %%
known_mechanics = set(['Charge', 'Stealth', 'Windfury', 'Taunt', 'Divine Shield'])

vanilla_minions_df = pandas.DataFrame(
    all_collectible_cards_df[(all_collectible_cards_df['type'] == 'Minion')])

vanilla_minions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 339 entries, 0 to 534
# Data columns (total 12 columns):
# attack            339 non-null float64
# cost              339 non-null int64
# durability        0 non-null float64
# health            339 non-null float64
# id                339 non-null object
# mechanics         233 non-null object
# name              339 non-null object
# playerClass       110 non-null object
# text              325 non-null object
# type              339 non-null object
# intrinsic         339 non-null int64
# text_mechanics    339 non-null object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.4+ KB

# %%
# Set/modify the pricing attributes based on mechanics
vanilla_minions_df['charge'] = vanilla_minions_df.apply(
    lambda row: row['attack'] if (isinstance(row['mechanics'], list) and 'Charge' in row['mechanics']) else 0, axis=1)
vanilla_minions_df['stealth'] = vanilla_minions_df.apply(
    lambda row: row['attack'] if (isinstance(row['mechanics'], list) and 'Stealth' in row['mechanics']) else 0, axis=1)
vanilla_minions_df['windfury'] = vanilla_minions_df.apply(
    lambda row: row['attack'] if (isinstance(row['mechanics'], list) and 'Windfury' in row['mechanics']) else 0, axis=1)
vanilla_minions_df['taunt'] = vanilla_minions_df.apply(
    lambda row: row['health'] if (isinstance(row['mechanics'], list) and 'Taunt' in row['mechanics']) else 0, axis=1)
vanilla_minions_df['divine_shield'] = vanilla_minions_df.apply(
    lambda row: row['attack'] if (isinstance(row['mechanics'], list) and 'Divine Shield' in row['mechanics']) else 0, axis=1)

# %%
vanilla_minions_df[['name', 'cost', 'attack', 'health', 'charge', 'stealth', 'windfury', 'taunt', 'divine_shield']]
# Out:
#                          name  cost  attack  health  charge  stealth  \
# 0                 Abomination     5       4       4       0        0
# 1            Abusive Sergeant     1       2       1       0        0
# 2             Acolyte of Pain     3       1       3       0        0
# 3        Al'Akir the Windlord     8       3       5       3        0
# 4                 Alarm-o-Bot     3       0       3       0        0
# 5           Aldor Peacekeeper     3       3       3       0        0
# 6                 Alexstrasza     9       8       8       0        0
# 7             Amani Berserker     2       2       3       0        0
# 9          Ancient Brewmaster     4       5       4       0        0
# 10               Ancient Mage     4       2       5       0        0
# 11            Ancient Watcher     2       4       5       0        0
# 12            Ancient of Lore     7       5       5       0        0
# 13             Ancient of War     7       5       5       0        0
# 14              Angry Chicken     1       1       1       0        0
# 15         Arathi Weaponsmith     4       3       3       0        0
# 16               Arcane Golem     3       4       2       4        0
# 17         Archmage Antonidas     7       5       7       0        0
# 18           Argent Commander     6       4       2       4        0
# 19           Argent Protector     2       2       2       0        0
# 20              Argent Squire     1       1       1       0        0
# 21                 Armorsmith     2       1       4       0        0
# 22        Auchenai Soulpriest     4       3       5       0        0
# 24                Azure Drake     5       4       4       0        0
# 26               Baron Geddon     7       7       5       0        0
# 30            Big Game Hunter     3       4       2       0        0
# 36                  Blood Imp     1       0       1       0        0
# 37               Blood Knight     3       3       3       0        0
# 38          Bloodmage Thalnos     2       1       1       0        0
# 39          Bloodsail Corsair     1       1       2       0        0
# 40           Bloodsail Raider     2       2       3       0        0
# ..                        ...   ...     ...     ...     ...      ...
# 498             Quartermaster     5       2       5       0        0
# 499            Recombobulator     2       3       2       0        0
# 502                 Salty Dog     5       7       4       0        0
# 503          Scarlet Purifier     3       4       3       0        0
# 504         Screwjank Clunker     4       2       5       0        0
# 506              Shadowbomber     1       2       1       0        0
# 507               Shadowboxer     2       2       3       0        0
# 508          Shielded Minibot     2       2       2       0        0
# 509              Shieldmaiden     6       5       5       0        0
# 510             Ship's Cannon     2       2       3       0        0
# 511             Shrinkmeister     2       3       2       0        0
# 512              Siege Engine     5       5       5       0        0
# 513      Siltfin Spiritwalker     4       2       5       0        0
# 514      Sneed's Old Shredder     8       5       7       0        0
# 515               Snowchugger     2       2       3       0        0
# 516               Soot Spewer     3       3       3       0        0
# 517               Spider Tank     3       3       4       0        0
# 518       Steamwheedle Sniper     2       2       3       0        0
# 519       Stonesplinter Trogg     2       2       3       0        0
# 520              Target Dummy     0       0       2       0        0
# 522     Tinkertown Technician     3       3       3       0        0
# 523                   Toshley     6       5       7       0        0
# 524     Trade Prince Gallywix     6       5       8       0        0
# 526  Troggzor the Earthinator     7       6       6       0        0
# 528       Upgraded Repair Bot     5       5       5       0        0
# 530            Vitality Totem     2       0       3       0        0
# 531                   Vol'jin     5       6       2       0        0
# 532                    Warbot     1       1       3       0        0
# 533          Wee Spellstopper     4       2       5       0        0
# 534      Whirling Zap-o-matic     2       3       2       0        0
#
#      windfury  taunt  divine_shield
# 0           0      4              0
# 1           0      0              0
# 2           0      0              0
# 3           3      5              3
# 4           0      0              0
# 5           0      0              0
# 6           0      0              0
# 7           0      0              0
# 9           0      0              0
# 10          0      0              0
# 11          0      0              0
# 12          0      0              0
# 13          0      0              0
# 14          0      0              0
# 15          0      0              0
# 16          0      0              0
# 17          0      0              0
# 18          0      0              4
# 19          0      0              0
# 20          0      0              1
# 21          0      0              0
# 22          0      0              0
# 24          0      0              0
# 26          0      0              0
# 30          0      0              0
# 36          0      0              0
# 37          0      0              0
# 38          0      0              0
# 39          0      0              0
# 40          0      0              0
# ..        ...    ...            ...
# 498         0      0              0
# 499         0      0              0
# 502         0      0              0
# 503         0      0              0
# 504         0      0              0
# 506         0      0              0
# 507         0      0              0
# 508         0      0              2
# 509         0      0              0
# 510         0      0              0
# 511         0      0              0
# 512         0      0              0
# 513         0      0              0
# 514         0      0              0
# 515         0      0              0
# 516         0      0              0
# 517         0      0              0
# 518         0      0              0
# 519         0      0              0
# 520         0      2              0
# 522         0      0              0
# 523         0      0              0
# 524         0      0              0
# 526         0      0              0
# 528         0      0              0
# 530         0      0              0
# 531         0      0              0
# 532         0      0              0
# 533         0      0              0
# 534         3      0              0
#
# [339 rows x 9 columns]

# %%
import numpy

a = vanilla_minions_df.as_matrix(['attack', 'health', 'intrinsic', 'charge', 'stealth', 'windfury', 'taunt', 'divine_shield'])
b = vanilla_minions_df.as_matrix(['cost'])
cost_per_point = numpy.linalg.lstsq(a, b)[0]
cost_per_point
# Out:
# array([[ 0.51013597],
#        [ 0.53345198],
#        [-0.09774491],
#        [ 0.15715708],
#        [-0.0054474 ],
#        [ 0.0519493 ],
#        [-0.06106898],
#        [ 0.30533601]])

# %%
card_value = cost_per_point[2][0]
vanilla_minions_df['value'] = numpy.dot(a, cost_per_point).T[0]
vanilla_minions_df['boost'] = (vanilla_minions_df['value'] + card_value) / \
    (vanilla_minions_df['cost'] + card_value)
vanilla_minions_df[['name', 'cost', 'value', 'boost']].sort('boost', ascending=False)
# Out:
#                      name  cost     value      boost
# 274           Zombie Chow     1  2.718373   2.904531
# 90              Flame Imp     1  2.695057   2.878689
# 11        Ancient Watcher     2  4.805549   2.474854
# 71             Dust Devil     1  2.317453   2.460178
# 532                Warbot     1  2.208237   2.339130
# 359     Northshire Cleric     1  2.208237   2.339130
# 143             Mana Wyrm     1  2.208237   2.339130
# 148   Millhouse Manastorm     2  4.272097   2.194423
# 398            Voidwalker     1  2.025030   2.136075
# 195          Shieldbearer     1  1.987277   2.094233
# 115   Injured Blademaster     3  5.872453   1.989731
# 68              Doomsayer     2  3.831909   1.963020
# 390              Succubus     2  3.738645   1.913991
# 123            King Mukla     3  5.315685   1.797892
# 429             Cogmaster     1  1.674785   1.747887
# 269            Undertaker     1  1.674785   1.747887
# 109           Hungry Crab     1  1.674785   1.747887
# 39      Bloodsail Corsair     1  1.674785   1.747887
# 157     Murloc Tidecaller     1  1.674785   1.747887
# 133           Lightwarden     1  1.674785   1.747887
# 188          Secretkeeper     1  1.674785   1.747887
# 129           Leper Gnome     1  1.651469   1.722045
# 399         Voodoo Doctor     1  1.651469   1.722045
# 356         Murloc Raider     1  1.651469   1.722045
# 1        Abusive Sergeant     1  1.651469   1.722045
# 425       Clockwork Gnome     1  1.651469   1.722045
# 506          Shadowbomber     1  1.651469   1.722045
# 242       Young Priestess     1  1.651469   1.722045
# 206     Southsea Deckhand     1  1.651469   1.722045
# 239    Worgen Infiltrator     1  1.640574   1.709970
# ..                    ...   ...       ...        ...
# 106                Hogger     6  4.272097   0.707247
# 121             Kidnapper     6  4.248781   0.703297
# 424       Clockwork Giant    12  8.446449   0.701439
# 156        Mountain Giant    12  8.446449   0.701439
# 3    Al'Akir the Windlord     8  5.533395   0.687861
# 132            Lightspawn     4  2.765005   0.683518
# 467                Jeeves     4  2.741689   0.677543
# 60      Defender of Argus     4  2.718373   0.671568
# 440     Enhance-o Mechano     4  2.695057   0.665593
# 227        Twilight Drake     4  2.671741   0.659618
# 485             Mini-Mage     4  2.649951   0.654034
# 468               Junkbot     5  3.275141   0.648150
# 84   Faceless Manipulator     5  3.228509   0.638637
# 420           Bomb Lobber     5  3.228509   0.638637
# 416       Antique Healbot     5  3.228509   0.638637
# 387    Stormpike Commando     5  3.205193   0.633881
# 36              Blood Imp     1  0.631197   0.591243
# 261          Nerubian Egg     2  1.164649   0.560863
# 4             Alarm-o-Bot     3  1.698101   0.551418
# 141       Mana Tide Totem     3  1.698101   0.551418
# 410      Captain's Parrot     2  1.141333   0.548606
# 38      Bloodmage Thalnos     2  1.141333   0.548606
# 360       Novice Engineer     2  1.141333   0.548606
# 441       Explosive Sheep     2  1.141333   0.548606
# 214      Summoning Portal     4  2.231553   0.546814
# 165      Patient Assassin     2  1.135885   0.545742
# 385      Starving Buzzard     5  2.695057   0.529820
# 154          Molten Giant    20  8.446449   0.419485
# 520          Target Dummy     0  1.042511  -9.665628
# 238                  Wisp     0  1.141333 -10.676647
#
# [339 rows x 4 columns]

# %% [markdown]
# ## 2-cost minions

# %%
two_cost_minions_df = all_collectible_cards_df[(all_collectible_cards_df['type'] == 'Minion') &
                                               (all_collectible_cards_df['cost'] == 2)]
print('2-cost minion mean attack: {:.2f}'.format(two_cost_minions_df.attack.mean()))
print('2-cost minion mean health: {:.2f}'.format(two_cost_minions_df.health.mean()))
# Out:
# 2-cost minion mean attack: 1.88
# 2-cost minion mean health: 2.45
