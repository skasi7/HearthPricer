# %%
import numpy
import os.path
import pandas

import hearthpricer.card_loader
import hearthpricer.card_pricer

all_sets_filename = os.path.join('data', 'AllSets.json')

card_list = hearthpricer.card_loader.load(all_sets_filename) #, include_class_cards=False)
len(card_list)
# Out:
# 54

# %%
minions_df = pandas.DataFrame(card_list)
minions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 53
# Data columns (total 9 columns):
# attack           54 non-null int64
# charge           54 non-null int64
# cost             54 non-null int64
# divine shield    54 non-null int64
# health           54 non-null int64
# name             54 non-null object
# stealth          54 non-null int64
# taunt            54 non-null int64
# windfury         54 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 4.0+ KB

# %%
coeffs = hearthpricer.card_pricer.pricing(minions_df, columns=[
        u'attack', u'charge', u'divine shield', u'health', u'stealth', u'taunt', u'windfury',
        'intrinsic'], debug=True)
# Out:
#      attack    charge  divine shield   health   stealth     taunt  windfury  \
# 0  1.190915  0.621821       2.271799  0.90042  0.650383  0.206659  0.670377
#
#    intrinsic
# 0   0.095389

# %%
card_value = coeffs[-1][0]
minions_df['value'] = (minions_df['price'] - minions_df['budget']) / (minions_df['cost'] + card_value)
minions_df[['name', 'cost', 'price', 'value']].sort('value', ascending=False)
# Out:
#                     name  cost      price      value
# 52          Target Dummy     0   2.118769  11.728495
# 15                  Wisp     0   1.995946  10.440895
# 39            Voidwalker     1   4.416764   1.293389
# 9           Shieldbearer     1   4.332928   1.216853
# 2          Argent Squire     1   4.267745   1.157347
# 53  Whirling Zap-o-matic     2   7.289329   1.092555
# 16    Worgen Infiltrator     1   3.837245   0.764336
# 50      Shielded Minibot     2   6.359081   0.648605
# 45       Gilblin Stalker     2   5.638085   0.304519
# 5             King Krush     9  21.609864   0.286944
# 25     Goldshire Footman     1   3.309685   0.282717
# 42          Annoy-o-Tron     2   5.581483   0.277506
# 28        Kor'kron Elite     4   9.856817   0.209215
# 31         Murloc Raider     1   3.186862   0.170590
# 49             Salty Dog     5  11.842699   0.165385
# 26    Ironbark Protector     8  18.288568   0.159173
# 18       Bloodfen Raptor     2   5.278197   0.132766
# 48         Puddlestomper     2   5.278197   0.132766
# 47      Lost Tallstrider     4   9.460868   0.112533
# 21      Boulderfist Ogre     6  13.353044   0.057920
# 22        Chillwind Yeti     4   9.170373   0.041601
# 4         Jungle Panther     3   7.119496   0.038604
# 51           Spider Tank     3   7.079038   0.025534
# 0   Al'Akir the Windlord     8  17.172278   0.021281
# 23            Core Hound     7  15.124950   0.017610
# 35   Sen'jin Shieldmasta     4   9.012753   0.003114
# 11   Stranglethorn Tiger     5  11.011672   0.002291
# 34       River Crocolisk     2   4.987702  -0.005869
# 44        Force-Tank MAX     8  16.815758  -0.022759
# 6       Mogu'shan Warden     4   8.845081  -0.037828
# 40             War Golem     7  14.543959  -0.064273
# 27       Ironfur Grizzly     3   6.798595  -0.065066
# 29     Lord of the Arena     6  12.585499  -0.068002
# 30           Magma Rager     3   6.759608  -0.077661
# 12             Sunwalker     6  12.475467  -0.086054
# 32         Oasis Snapjaw     4   8.589382  -0.100263
# 8       Scarlet Crusader     3   6.649576  -0.113208
# 10   Silvermoon Guardian     4   8.450416  -0.134196
# 20   Booty Bay Bodyguard     5  10.287505  -0.139831
# 3            Fen Creeper     5  10.119832  -0.172738
# 14        Windfury Harpy     6  11.851882  -0.188359
# 13     Thrallmar Farseer     3   6.328456  -0.216950
# 7    Ravenholdt Assassin     7  13.393502  -0.226414
# 38      Stormwind Knight     4   8.032185  -0.236318
# 24       Frostwolf Grunt     2   4.500600  -0.238333
# 41             Wolfrider     3   6.243241  -0.244480
# 19      Bluegill Warrior     2   4.430504  -0.271785
# 46   Gnomeregan Infantry     3   6.145664  -0.276003
# 1       Argent Commander     6  11.228196  -0.290679
# 17      Young Dragonhawk     1   2.666324  -0.304619
# 37        Stonetusk Boar     1   2.617768  -0.348947
# 33    Reckless Rocketeer     6  10.769134  -0.365992
# 36  Silverback Patriarch     3   5.523843  -0.476889
# 43        Flying Machine     3   5.367584  -0.527370
